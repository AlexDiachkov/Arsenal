# %%
import pandas as pd
u= pd.read_csv('ttt2_1.csv')

# %%
u.head(15)
# Out:
#     № п/п      №\nдокумента  Дата\nрегистрации  \
# 0       1    WSR/1-838/2019            43564.0
# 1       2    WSR/1-837/2019            43564.0
# 2       3    WSR/1-835/2019            43564.0
# 3       4    WSR/1-834/2019            43564.0
# 4       5    WSR/1-833/2019            43564.0
# 5       6    WSR/1-831/2019            43564.0
# 6       7    WSR/1-830/2019            43564.0
# 7       8  WSR/1.6-832/2019            43564.0
# 8       9    WSR/1-836/2019            43564.0
# 9      10    WSR/1-829/2019            43563.0
# 10     11  WSR/1.4-828/2019            43563.0
# 11     12    WSR/1-827/2019            43563.0
# 12     13    WSR/1-826/2019            43563.0
# 13     14    WSR/1-825/2019            43563.0
# 14     15  WSR/1.6-824/2019            43563.0
#
#                         Исх. №\nДата           Адресат  \
# 0                208-409\n08.04.2019       Уразов Р.Н.
# 1                 05-338\n09.04.2019       Уразов Р.Н.
# ...
